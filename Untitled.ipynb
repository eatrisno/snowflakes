# %%
import requests
from bs4 import BeautifulSoup

# %%
page = requests.get("http://dataquestio.github.io/web-scraping-pages/ids_and_classes.html")
soup = BeautifulSoup(page.content, 'html.parser')

# %%
print soup
# Out:
# <html>
# <head>
# <title>A simple example page</title>
# </head>
# <body>
# <div>
# <p class="inner-text first-item" id="first">
#                 First paragraph.
#             </p>
# <p class="inner-text">
#                 Second paragraph.
#             </p>
# </div>
# <p class="outer-text first-item" id="second">
# <b>
#                 First outer paragraph.
#             </b>
# </p>
# <p class="outer-text">
# <b>
#                 Second outer paragraph.
#             </b>
# </p>
# </body>
# </html>

# %%
from selenium import webdriver
browser = webdriver.Chrome("./driver/chromedriver")

# %%
browser.get('https://tokopedia.com/login')

# %%
print browser.page_source
# Out:
# <!DOCTYPE html><!--[if IE 7 ]><html class="no-js ie7 oldie" dir="ltr" lang="id"><![endif]--><!--[if IE 8 ]><html class="no-js ie8 oldie" dir="ltr" lang="id"><![endif]--><!--[if (gte IE 9)|(gt IEMobile 7)|!(IEMobile)|!(IE)]><!--><html xmlns="http://www.w3.org/1999/xhtml" class="no-js svg" dir="ltr" lang="id" data-react-helmet="dir,lang"><!--<![endif]--><head><script async="true" type="text/javascript" src="https://sslwidget.criteo.com/event?a=20100&amp;v=4.7.0&amp;p0=e%3Dce%26m%3D%255B%255D&amp;p1=e%3Dexd%26site_type%3Dd&amp;p2=e%3Dvh&amp;p3=e%3Ddis&amp;adce=1&amp;lwid=1f048650-1e3c-4c0f-8569-5c359d4a1b7e&amp;tld=tokopedia.com&amp;dtycbr=82759" data-owner="criteo-tag"></script><script type="text/javascript" async="" src="https://www.google-analytics.com/gtm/js?id=GTM-T9Q3S3H&amp;t=gtm1&amp;cid=834759063.1533918440"></script> <title>Jual Beli Online Aman dan Nyaman - Tokopedia</title> <meta data-react-helmet="true" http-equiv="Content-Type" content="text/html; charset=utf-8" /><meta data-react-helmet="true" name="viewport" content="width=device-width, initial-scale=1.0" /><meta data-react-helmet="true" name="format-detection" content="telephone=no" /><meta data-react-helmet="true" name="p:domain_verify" content="50de202304b80ee007bc5d73425457ba" /><meta data-react-helmet="true" name="msvalidate.01" content="3104E882307BB6900F56D266DC8320F6" /><meta data-react-helmet="true" property="og:site_name" content="Tokopedia" /><meta data-react-helmet="true" name="title" content="Jual Beli Online Aman dan Nyaman - Tokopedia" /><meta data-react-helmet="true" name="description" content="Mal online terbesar Indonesia, tempat berkumpulnya toko / online shop terpercaya se Indonesia. Jual beli online semakin aman dan nyaman di Tokopedia." /><meta data-react-helmet="true" property="og:title" content="Jual Beli Online Aman dan Nyaman - Tokopedia" /><meta data-react-helmet="true" property="og:description" content="Mal online terbesar Indonesia, tempat berkumpulnya toko / online shop terpercaya se Indonesia. Jual beli online semakin aman dan nyaman di Tokopedia." /><meta data-react-helmet="true" property="og:url" content="https://www.tokopedia.com/" /><meta data-react-helmet="true" name="branch:deeplink:$ios_deeplink_path" content="/" /><meta data-react-helmet="true" name="branch:deeplink:$android_deeplink_path" content="/" /><meta data-react-helmet="true" name="branch:deeplink:$desktop_url" content="https://www.tokopedia.com/" /><meta data-react-helmet="true" name="branch:deeplink:$android_url" content="https://www.tokopedia.com/" /><meta data-react-helmet="true" name="branch:deeplink:$ios_url" content="https://www.tokopedia.com/" /> <link data-react-helmet="true" href="https://plus.google.com/104285007928921240758" rel="publisher" /><link data-react-helmet="true" rel="dns-prefetch" href="//ecs12.tokopedia.net" /><link data-react-helmet="true" rel="dns-prefetch" href="//ecs7.tokopedia.net" /><link data-react-helmet="true" rel="dns-prefetch" href="//js.tokopedia.com" /><link data-react-helmet="true" rel="dns-prefetch" href="//mojito.tokopedia.com" /><link data-react-helmet="true" rel="dns-prefetch" href="//accounts.tokopedia.com" /><link data-react-helmet="true" rel="dns-prefetch" href="//www.google-analytics.com" /><link data-react-helmet="true" rel="dns-prefetch" href="//www.googletagmanager.com" /><link data-react-helmet="true" rel="prefetch" href="https://ecs7.tokopedia.net/img/search_improvment/toped_error_small.png" as="image" /><link data-react-helmet="true" rel="prefetch" href="https://cdn.tokopedia.net/fonts/Tokopedia.woff" as="font" /><link data-react-helmet="true" rel="prefetch" href="https://cdn.tokopedia.net/fonts/OpenSans-Regular.woff" as="font" /><link data-react-helmet="true" rel="prefetch" href="https://cdn.tokopedia.net/fonts/OpenSans-Semibold.woff" as="font" /><link data-react-helmet="true" rel="prefetch" href="https://cdn.tokopedia.net/fonts/OpenSans-Bold.woff" as="font" /><link data-react-helmet="true" href="https://fonts.googl ...
# <link rel="stylesheet" href="https://ecs7.tokopedia.net/assets-frontend-discovery/production/home-894e7073a859542d3e2cf940ae9a8cbf.css" />
# <link rel="stylesheet" href="https://ecs7.tokopedia.net/assets-frontend-discovery/production/home-non-login-0d191b5b28d220b45fda54d8e7105901.css" /> <!--[if lt IE 9]>
#         <script src="https://ecs7.tokopedia.net/scripts/html5shiv.min.js?v=1499751141"></script>
#         <![endif]--><script type="text/javascript" async="" src="//js.betaout.com/jal-v2.min.js"></script><script type="text/javascript" async="" src="//static.criteo.net/js/ld/ld.js"></script><script async="" src="//static.ads-twitter.com/uwt.js"></script><script type="text/javascript" async="" src="https://tokopedia.api.sociaplus.com/partner.js"></script><script type="text/javascript" async="" src="https://d31qbv1cthcecs.cloudfront.net/atrk.js"></script><script src="https://connect.facebook.net/signals/config/1419424518349836?v=2.8.24&amp;r=stable" async=""></script><script async="" src="//connect.facebook.net/en_US/fbevents.js"></script><script type="text/javascript" async="" src="https://www.google-analytics.com/analytics.js"></script><script async="" src="https://cdn.branch.io/branch-latest.min.js"></script><script async="" src="//www.googletagmanager.com/gtm.js?id=GTM-TN8CNF"></script><script src="https://cdn.onesignal.com/sdks/OneSignalSDK.js" async=""></script> <script type="text/javascript">window.__CSS_CHUNKS__= {"home":"https://ecs7.tokopedia.net/assets-frontend-discovery/production/home-894e7073a859542d3e2cf940ae9a8cbf.css","search":"https://ecs7.tokopedia.net/assets-frontend-discovery/production/search-d984d2cad03cc4e2acdcb3d4ae0ec15e.css","hotlist-detail":"https://ecs7.tokopedia.net/assets-frontend-discovery/production/hotlist-detail-12c9988a626b60e7afb5484192ada217.css","catalog-detail":"https://ecs7.tokopedia.net/assets-frontend-discovery/production/catalog-detail-37a90725ed57b22dc04d3fe675064d63.css","hotlist":"https://ecs7.tokopedia.net/assets-frontend-discovery/production/hotlist-e598635e8f813a510cd1ff6398334dd6.css","main":"https://ecs7.tokopedia.net/assets-frontend-discovery/production/main-7c19c46300ef4585204356c5fcf9ffa9.css","home-login":"https://ecs7.tokopedia.net/assets-frontend-discovery/production/home-login-4e88710e688be061c7ea86c4c87c83e5.css","home-non-login":"https://ecs7.tokopedia.net/assets-frontend-discovery/production/home-non-login-0d191b5b28d220b45fda54d8e7105901.css"}</script> <script>
#                 window.__data = {"app":{"user":{"adminID":0,"fullName":"","userEmail":"","lang":"id","status":1,"rememberMe":0,"shopID":0,"sex":2,"createTime":0,"uniqueID":"c40235244e1744f1a4c03fd7700177d5","connectionStatus":"online"},"experiment":{},"onboarding":{"active":{},"list":{}}},"home":{"widget":{"meta":{"home_status":"loading","os_status":"success","hotlist_status":"success","toppicks_status":"loading","status":"success"},"data":{"channel":[],"ticker":[],"sprintSale":[],"officialStore":[{"name":"Popular Brand","value":"0","shops":[{"id":3498343,"url":"https:\u002F\u002Fwww.tokopedia.com\u002Fjedar-cosmetic","name":"Jedar Cosmetic Official","imageURL":"https:\u002F\u002Fecs7.tokopedia.net\u002Fimg\u002Fcache\u002F244\u002Fattachment\u002F2018\u002F7\u002F6\u002F31924013\u002F31924013_7b24b456-fe98-4a7b-85d9-72d3c3fa64ec.png","isNew":true,"position":1},{"id":3684253,"url":"https:\u002F\u002Fwww.tokopedia.com\u002Fmamamiaindonesia","name":"Mamamia Indonesia","imageURL":"https:\u002F\u002Fecs7.tokopedia.net\u002Fimg\u002Fcache\u002F244\u002Fattachment\u002F2018\u002F7\u002F30\u002F25568798\u002F25568798_90982890-bb65-41db-86f1-e68fda4b4105.png","isNew":true,"position":2},{"id":2706562,"url":"https:\u002F\u002Fwww.tokopedia.com\u002Fwd-official","name":"WD Official Store","imageURL":"https:\u002F\u002Fecs7.tokopedia.net\u002Fimg\u002Fcache\u002F244\u002Fattachment\u002F2017\u002F12\u002F15\u002F24962071\u002F24962071_ca0027fc-0bf9-45a6-beb0-4e342d410be4.png","isNew":true,"position":3},{"id":3685471,"url":"https:\u002F\u002Fwww.tokopedia.com\u002Flevistrauss","name":"Levi's Official Store","imageURL":"https:\u002F\u002Fecs7.tokopedia.net\u002Fimg\u002Fcache\u002F244\u002Fattachment\u002F2018\u002F7\u002F30\u002F25568798\u002F25568798_b263e4d7-9aa8-4d54-a2b7-08f4a7185d9b.png","isNew":true,"position":4},{"id":3622447,"url":"https:\u002F\u002Fwww.tokopedia.com\u002Fsaintbysandra","name":"SAINT by Sandra","imageURL":"https:\u002F\u002Fecs7.tokopedia.net\u002Fimg\u002Fcache\u002F244\u002Fattachment\u002F2018\u002F7\u002F10\u002F31924013\u002F31924013_fb7b9e21-c9ce-4a74-a067-ce7ce8e87541.png","isNew":false,"position":5},{"id":3604388,"url":"https:\u002F\u002Fwww.tokopedia.com\u002Ffujitsu-id","name":"FUJITSU OFFICIAL STORE","imageURL":"https:\u002F\u002Fecs7.tokopedia.net\u002Fimg\u002Fcache\u002F244\u002Fattachment\u002F2018\u002F7\u002F26\u002F25568798\u002F25568798_3b3c5258-f1af-427e-81dd-6e4affcdfda3.jpeg","isNew":true,"position":6},{"id":2719819,"url":"https:\u002F\u002Fwww.tokopedia.com\u002Fweddingku","name":"Weddingku","imageURL":"https:\u002F\u002Fecs7.tokopedia.net\u002Fimg\u002Fcache\u002F244\u002Fattachment\u002F2018\u002F7\u002F26\u002F25568798\u002F25568798_ba021fdc-56c8-4e1b-88ca-d7ebf6590715.png","isNew":true,"position":7},{"id":3576849,"url":"https:\u002F\u002Fwww.tokopedia.com\u002Ftoshiba-ac","name":"Toshiba Air Conditioning","imageURL":"https:\u002F\u002Fecs7.tokopedia.net\u002Fimg\u002Fcache\u002F244\u002Fattachment\u002F2018\u002F7\u002F20\u002F27025623\u002F27025623_5b96c8ea-6561-4920-a30d-79a6c5a51b95.png","isNew":true,"position":8},{"id":3655849,"url":"https:\u002F\u002Fwww.tokopedia.com\u002Favoskinofficial","name":"Avoskin","imageURL":"https:\u002F\u002Fecs7.tokopedia.net\u002Fimg\u002Fcache\u002F244\u002Fattachment\u002F2018\u002F7\u002F25\u002F25568798\u002F25568798_4aa79d51-e786-4f12-8067-25145953c77f.png","isNew":true,"position":9},{"id":3649468,"url":"https:\u002F\u002Fwww.tokopedia.com\u002Fsakroots-id","name":"Sakroots Indonesia","imageURL":"https:\u002F\u002Fecs7.tokopedia.net\u002Fimg\u002Fcache\u002F244\u002Fattachment\u002F2018\u002F7\u002F23\u002F31924013\u002F31924013_9ff3a637-426a-4ee9-a990-afcd57ee47f2.png","isNew":true,"position":10},{"id":588638,"url":"https:\u002F\u002Fwww.tokopedia.com\u002Fhondacengkareng","name":"Honda Cengkareng","imageURL":"https:\u002F\u002Fecs7.tokopedia.net\u002Fimg\u002Fcache\u002F244\u002Fattachment\u002F2018\u002F7\u002F26\u002F15012939\u002F15012939_a6596 ...
#
#
#                 window.__apollo = {};
#
#
#                  self.AUTOCOMPLETE_SERVICE_URL = 'https://ace.tokopedia.com/universe/v5';  var lp_url = 'https://points.tokopedia.com';  var reputation_score_url = 'https://www.tokopedia.com/reputationapp/reputation/api/v1/';  var reputation_badge_off = 'https://ecs7.tokopedia.net/img/badges-off.jpg';  var seller_info_url = 'https://gw.tokopedia.com/sellerinfo/';  var seller_info_url_mobile = 'https://gw.tokopedia.com/sellerinfo/';  var product_ads_ajax_go = 'https://ta.tokopedia.com';  var product_ads_ajax_url = 'https://www.tokopedia.com/ajax/promo.pl';  var product_dink_ajax_url = 'https://www.tokopedia.com/ajax/promo-na.pl';  var shop_ads_ajax_url = 'https://www.tokopedia.com/ajax/promo.pl';  var manage_ads_ajax_url = 'https://www.tokopedia.com/ajax/shop/manage-ad.pl';  var pio_ads_queries_url = 'https://pio.tokopedia.com/queries.json';  var microsite_ads_url = 'https://www.tokopedia.com/iklan';  var sidebar_ads_ajax_go = 'https://ta.tokopedia.com';  var merlin_nf_recommendation = 'https://merlin.tokopedia.com';  var gm_sidebar_url = 'https://goldmerchant.tokopedia.com/v1/shopstats/shopscore/sum/';  var gold_sidebar_auth = '';  var gold_sidebar_date = '';  var gold_sidebar_md5 = '';  var search_ajax_product_url = 'https://ace.tokopedia.com/search/v2.6/product';  var search_ajax_product_url_v3 = 'https://ace.tokopedia.com/search/product/v3';  var search_ajax_product_attribute_url = 'https://ace.tokopedia.com/search/product/attributes/v3';  var search_ajax_related_keyword = 'https://ace.tokopedia.com/related/v1';  var search_ajax_catalog_url = 'https://ace.tokopedia.com/search/v1/catalog';  var search_ajax_shop_url = 'https://ace.tokopedia.com/search/v1/shop';  var spell_ajax_product_url = 'https://ace.tokopedia.com/search/v1/spell/product';  var search_ajax_catalog_product_url = 'https://ace.tokopedia.com/search/v1/catalog/product';  var search_ajax_catalog_price_range = 'https://ace.tokopedia.com/v1/price_range';  var search_ajax_dynamic_attributes = 'https://ace.tokopedia.com/v1/dynamic_attributes';  var search_ajax_dynamic_attributes_v11 = 'https://ace.tokopedia.com/v1.1/dynamic_attributes';  var search_ajax_dynamic_attributes_v2 = 'https://ace.tokopedia.com/v2/dynamic_attributes';  var domain = 'http://tokopedia.com';  var mobile_domain = 'http://m.tokopedia.com';  var host_tome = 'https://tome-staging.tokopedia.com';  var site_key = '6Lf5phwUAAAAAK4rbyFIEsgK77ysuT5a3i4H7FZn';  var iconClose = 'https://ecs7.tokopedia.net/img/search-filter/icon-close-copy.png';  var topchat_url = 'https://chat.tokopedia.com/tc/v1';
#             </script><script type="application/ld+json" data-react-helmet="true">{
#                     "@context": "http://schema.org",
#                     "@type": "WebSite",
#                     "url": "https://www.tokopedia.com",
#                     "potentialAction": {
#                         "@type": "SearchAction",
#                         "target": "https://www.tokopedia.com/search?q={search_term_string}",
#                         "query-input": "required name=search_term_string"
#                     }
#                 }</script><link rel="stylesheet" href="data:text/css,@import%20url%28%27https%3A//ecs7.tokopedia.net/css/recharge-widget-desktop-v3.css%3Fv%3D6%27%29%3B" /><style type="text/css">#digital_widget_desktop .dgw-dropdown__name, #digital_widget_desktop .dgw-dropdown__price { white-space: initial!important;word-break: initial!important }#digital_widget_desktop ::-webkit-scrollbar {width: 7px; -webkit-appearance: none; }#digital_widget_desktop ::-webkit-scrollbar-thumb {border-radius: 4px; background-color: rgba(0, 0, 0, 0.5); box-shadow: 0 0 1px rgba(255, 255, 255, 0.5); }#digital_widget_desktop .dgw-dropdown {min-width: 214px; top: 33px; border-radius: 3px; }</style><script type="text/javascript" async="" src="//api.sociaplus.com/js/squery.min.js"></script><link rel="stylesheet" type="text/css" href="https://js.betaout.com/boutapiv4.0.11-min.css" id="boutapicss" /></head><body style=""><!-- Google Tag Manager Prod --><noscript>&lt;iframe src="//www.googletagmanager.com/ns.html?id=GTM-TN8CNF&amp;nojscript=true"height="0"width="0"style="display:none;visibility:hidden"&gt;&lt;/iframe&gt;</noscript><script>!function(e,t,a,n,g){e[n]=e[n]||[],e[n].push({"gtm.start":(new Date).getTime(),event:"gtm.js"});var m=t.getElementsByTagName(a)[0],r=t.createElement(a);r.async=!0,r.src="//www.googletagmanager.com/gtm.js?id=GTM-TN8CNF",m.parentNode.insertBefore(r,m)}(window,document,"script","dataLayer")</script><script type="text/javascript">!function(e,t,n,r,i,a,o,c,d,s){if(!e[r]||!e[r]._q){for(;c&lt;o.length;)i(a,o[c++]);(d=t.createElement(n)).async=1,d.src="https://cdn.branch.io/branch-latest.min.js",(s=t.getElementsByTagName(n)[0]).parentNode.insertBefore(d,s),e[r]=a}}(window,document,"script","branch",function(e,t){e[t]=function(){e._q.push([t,arguments])}},{_q:[],_v:1},"addListener applyCode autoAppIndex banner closeBanner closeJourney creditHistory credits data deepview deepviewCta first getCode init link logout redeem referrals removeListener sendSMS setBranchViewData setIdentity track validateCode trackCommerceEvent logEvent".split(" "),0),branch.init("key_live_abhHgIh1DQiuPxdBNg9EXepdDugwwkHr",function(e,t){})</script><!-- End Google Tag Manager Prod -->  <header class="navbar navbar-fixed-top"><div class="navbar-inner"><div class="container-header-full clearfix"><div class="overlay"></div><div class="topbar-logo-wrapper"><a href="https://www.tokopedia.com/">Tokopedia<span class="site-logo"></span></a></div><ul class="topbar-nav inline pull-left mr-15"><li class="dropdown-hover dropdown-topbar-category"><a class="dropdown-hover-toggle" href="javascript:void(0);">Kategori<i class="icon-chevron-down-alt fs-14"></i></a><div class="dropdown-menu"><div class="holder-dropdown-menu dropdown-category-thumb-v2" style="height: 70vh; overflow: auto;"><div class="row-fluid"><div class="span3"><ul class="allcat-head"><li><a href="https://www.tokopedia.com/p/fashion-wanita"><div class="cat-inner"><div class="wrap__sprite-cat-home"><img src="https://ecs7.tokopedia.net/img/category/new/v1/icon_fashion_woman.png" /></div><span class="title">Fashion Wanita</span></div></a></li><li><a href="https://www.tokopedia.com/p/fashion-pria"><div class="cat-inner"><div class="wrap__sprite-cat-home"><img src="https://ecs7.tokopedia.net/img/category/new/v1/icon_fashion_man.png" /></div><span class="title">Fashion Pria</span></div></a></li><li><a href="https://www.tokopedia.com/p/fashion-muslim"><div class="cat-inner"><div class="wrap__sprite-cat-home"><img src="https://ecs7.tokopedia.net/img/category/new/v1/icon_fashion_muslim.png" /></div><span class="title">Fashion Muslim</span></div></a></li><li><a href="https://www.tokopedia.com/p/fashion-anak"><div class="cat-inner"><div class="wrap__sprite-cat-home"><img src="https://ecs7.tokopedia.net/img/category/new/v1/icon_fashion_anak.png" /></div><span class="title">Fashion Anak</span></div></a></li><li><a href="https://www.tokopedia.com/p/kecantikan"><div class="cat-inner"><div class="wrap__sprite-cat-home"> ...
#                     "@context": "http://schema.org",
#                     "@type": "WebSite",
#                     "url": "https://www.tokopedia.com",
#                     "potentialAction": {
#                         "@type": "SearchAction",
#                         "target": "https://www.tokopedia.com/search?q={search_term_string}",
#                         "query-input": "required name=search_term_string"
#                     }
#                 }</script>  <script type="text/javascript" src="https://ecs7.tokopedia.net/assets-frontend-discovery/production/manifest-623a998ad871b87c0b64.js" defer=""></script>
# <script type="text/javascript" src="https://ecs7.tokopedia.net/assets-frontend-discovery/production/vendor-997616a5662862866254.js" defer=""></script>
# <script type="text/javascript" src="https://ecs7.tokopedia.net/assets-frontend-discovery/production/home-5a8c4ea41dc30635cf03.js" defer=""></script>
# <script type="text/javascript" src="https://ecs7.tokopedia.net/assets-frontend-discovery/production/home-non-login-cb14f25fb7aa7f90dca1.js" defer=""></script>
# <script type="text/javascript" src="https://ecs7.tokopedia.net/assets-frontend-discovery/production/main-106df9b22cb8ee1630f6.js" defer=""></script> <script type="text/javascript">var env="production",check_ios=!1;if(1==(check_ios=!!navigator.userAgent.match(/iPad|iPhone/gi))){var frame=document.createElement("iframe");frame.src="tokopedia://search?q=fghij&amp;st=product",frame.style.display="none",document.body.appendChild(frame),setTimeout(function(){document.body.removeChild(frame)},4)}window.gtm_search_filter=function(){window.dataLayer=window.dataLayer||[],dataLayer.push({event:"searchFilter",label:"new_search"})}</script>
# <script type="text/javascript" id="">!function(b,e,f,g,a,c,d){b.fbq||(a=b.fbq=function(){a.callMethod?a.callMethod.apply(a,arguments):a.queue.push(arguments)},b._fbq||(b._fbq=a),a.push=a,a.loaded=!0,a.version="2.0",a.queue=[],c=e.createElement(f),c.async=!0,c.src=g,d=e.getElementsByTagName(f)[0],d.parentNode.insertBefore(c,d))}(window,document,"script","//connect.facebook.net/en_US/fbevents.js");fbq("init","1419424518349836");fbq("track","PageView");</script>
# <noscript>&lt;img height="1" width="1" style="display:none" src="https://www.facebook.com/tr?id=1419424518349836&amp;amp;ev=PageView&amp;amp;noscript=1"&gt;</noscript>
# <script type="text/javascript" id="" src="//platform.twitter.com/oct.js"></script><script type="text/javascript" id="">_atrk_opts={atrk_acct:"dGA7f1a4IQ0087",domain:"tokopedia.com",dynamic:!0};(function(){var a=document.createElement("script");a.type="text/javascript";a.async=!0;a.src="https://d31qbv1cthcecs.cloudfront.net/atrk.js";var b=document.getElementsByTagName("script")[0];b.parentNode.insertBefore(a,b)})();</script><noscript>&lt;img src="https://d5nxst8fruw4z.cloudfront.net/atrk.gif?account=dGA7f1a4IQ0087" style="display:none" height="1" width="1" alt=""&gt;</noscript>
# <script type="text/javascript" id="">!function(){var f={atrk_acct:"dGA7f1a4IQ0087",domain:"tokopedia.com",dynamic:!0};(function(){var b={iu:"https://d5nxst8fruw4z.cloudfront.net/atrk.gif?",ver:"20130128",opts:{atrk_acct:"",domain:"",dynamic:!1},fired:function(){return"undefined"==typeof window._atrk_fired&amp;&amp;(window._atrk_fired=!1),window._atrk_fired},params:{frame_height:function(){return b.frame("innerHeight","clientHeight")},frame_width:function(){return b.frame("innerWidth","clientWidth")},iframe:function(){try{return window!==window.top?
# 1:0}catch(a){return b=a,0}},title:function(){return this.ue(document?document.title:"")},time:function(){var a;return a=new Date,a.getTime()+"\x26time_zone_offset\x3d"+a.getTimezoneOffset()},screen_params:function(){try{return screen.width+"x"+screen.height+"x"+screen.colorDepth}catch(a){b=a}return""},java_enabled:function(){return navigator&amp;&amp;"undefined"!=typeof navigator.javaEnabled?navigator.javaEnabled()?"1":"0":""},cookie_enabled:function(){return navigator&amp;&amp;"undefined"!=typeof navigator.cookieEnabled?
# navigator.cookieEnabled?"1":"0":""},ref_url:function(){return"string"==typeof document.referrer?b.ue(document.referrer):""},host_url:function(){return"string"==typeof window.location.href?b.ue(window.location.href):""},random_number:function(){return Math.round(21474836747*Math.random())},sess_cookie:function(){return b.gc("__asc",b.user_cookie_v,"sess_cookie",1800)},user_cookie:function(){return b.gc("__auc",b.user_cookie_v,"user_cookie",31622400)},dynamic:function(){return this.opts.dynamic.toString()},
# domain:function(){return"string"==typeof this.opts.domain?this.opts.domain:""},account:function(){return"string"==typeof this.opts.atrk_acct?this.opts.atrk_acct:""},jsv:function(){return this.ver},user_lang:function(){return window.navigator.userLanguage||window.navigator.language}},frame:function(a,e){if("undefined"!=typeof window[a])return window[a];if("undefined"!=typeof window.document[e])return window.document[e];try{return window.document.getElementsByTagName("body")[0][e]}catch(c){return"-"}},
# r:function(){return(65536*(1+Math.random())|0).toString(16).substring(1)},muc:function(){return this.r()+this.r()+(new Date).getTime().toString(16)+this.r()+this.r()},gc:function(a,e,c,b){var d="";var f=0;try{d=this.gbc(a)}catch(g){}return(null===d||0===d.length)&amp;&amp;(d=e,f=1),this.sbc(a,d,b),d+"\x26"+c+"_flag\x3d"+f},ue:function(a){try{return encodeURIComponent(a)}catch(e){return escape(a)}},gbc:function(a){var e,c,d;if(d=document.cookie,e=a+"\x3d",c=d.indexOf("; "+e),a=void 0,-1===c){if(c=d.indexOf(e),
# 0!==c)return null}else c+=2;return a=d.indexOf(";",c),-1===a&amp;&amp;(a=d.length),this.ue(d.substring(c+e.length,a))},sbc:function(a,e,c){var d=new Date;var b=this.dom();d.setTime(d.getTime()+1E3*c);document.cookie=a+"\x3d"+escape(e)+(c?"; expires\x3d"+d.toGMTString():"")+(b&amp;&amp;0&lt;b.length?"; domain\x3d."+b:"")+"; path\x3d/"},dom:function(){var a;return"string"==typeof this.opts.domain?this.opts.domain:(a=window.location.host,"www."===a.substr(0,4)?a.substr(4):a)},gen_url:function(){var a;try{return a=this,
# this.iu+this.map(this.params,function(b,c){return b+"\x3d"+c.call(a)}).join("\x26")}catch(e){return this.iu}},map:function(a,b){var c;var d=[];for(c in a)a.hasOwnProperty(c)&amp;&amp;d.push(b.call(this,c,a[c]));return d},cloudfront:{url:"http://cloudfront-labs.amazonaws.com/x.png",fire:function(){"http:"===location.protocol&amp;&amp;((new Image).src=b.cloudfront.url)}},user_cookie_v:"",fire:function(a){this.user_cookie_v=this.muc();this.map(a,function(a,b){this.opts[a]=b});window._atrk_fired=!0;a=new Image(1,1);
# a.alt="alexametrics";a.src=this.gen_url();this.cloudfront.fire()}};window.algx=function(a){b.setUrl=a;b.fire(f)};"undefined"!=typeof f&amp;&amp;"undefined"!=typeof f.dynamic&amp;&amp;f.dynamic&amp;&amp;algx()})()}.call(this);
# (function(){window.fireAlgx=function(f){return null==f&amp;&amp;(f=window.location.href),"undefined"!=typeof window.algx?window.algx(f):void 0};(function(){var f,b;return fireAlgx(),b="a[href^\x3d'/']",f=b.length,setTimeout(function(){var a,e;return a=b[Math.round(Math.random()*f)],a?(e=a.href,fireAlgx(e)):void 0,a},8E3)})()}).call(this);</script><script type="text/javascript" id="">analyticsEvent=function(a,b,c,d,e){dataLayer.push({event:"analyticsEvent",eventCategory:a,eventAction:b,eventLabel:c,eventValue:d,eventNonInt:e})};</script>            <script type="text/javascript" id="">var _spapi=_spapi||[];_spapi.push(["_partner","tokopedia"]);(function(){var a=document.createElement("script");a.type="text/javascript";a.async=!0;a.src=("https:"==document.location.protocol?"https://":"http://")+"tokopedia.api.sociaplus.com/partner.js";var b=document.getElementsByTagName("script")[0];b.parentNode.insertBefore(a,b)})();</script>   <script type="text/javascript" id="">(function(){var a=google_tag_manager["GTM-TN8CNF"].macro(2);count=5;if(a&amp;&amp;a.userId){if(a=document.getElementById("topup-wallet-button"))a.style.cssText="display:none !important";if(a=document.getElementById("topup-saldo-button"))a.style.cssText="display:none !important";var b=setInterval(function(){count--;var a=document.getElementById("topup-wallet-button");a&amp;&amp;(a.style.cssText="display:none !important");if(a=document.getElementById("topup-saldo-button"))a.style.cssText="display:none !important";0&gt;=count&amp;&amp;clearInterval(b)},
# 500)}})();</script>
# <script type="text/javascript" id="">!function(d,e,f,a,b,c){d.twq||(a=d.twq=function(){a.exe?a.exe.apply(a,arguments):a.queue.push(arguments)},a.version="1.1",a.queue=[],b=e.createElement(f),b.async=!0,b.src="//static.ads-twitter.com/uwt.js",c=e.getElementsByTagName(f)[0],c.parentNode.insertBefore(b,c))}(window,document,"script");twq("init","nuwgn");twq("track","PageView");</script>
#
#
# <script type="text/javascript" id="" src="https://www.googletagmanager.com/gtag/js?id=DC-8603974"></script><script type="text/javascript" id="">var _bout=_bout||[],_boutAKEY="la8jnjksma8jn8rhq14us9h4jlv8yhk47l54fjslv4",_boutPID="30045",d=document,f=d.getElementsByTagName("script")[0],_sc=d.createElement("script");_sc.type="text/javascript";_sc.async=!0;_sc.src="//js.betaout.com/jal-v2.min.js";f.parentNode.insertBefore(_sc,f);</script><script type="text/javascript" id="">var contact=google_tag_manager["GTM-TN8CNF"].macro(4),_bout=_bout||[];
# if(contact){var bout_update={};contact.gender&amp;&amp;(bout_update.gender=contact.gender);contact.dateLBExpired&amp;&amp;(bout_update.datelbexpired_date=contact.dateLBExpired);contact.dateLBExpired&amp;&amp;(bout_update.shop_name=contact.shopName);contact.dateLPExpired&amp;&amp;(bout_update.datelpexpired_date=contact.dateLPExpired);contact.userSeller&amp;&amp;(bout_update.isseller=contact.userSeller);contact.userFullName&amp;&amp;(bout_update.fullname=contact.userFullName);contact.userStatus&amp;&amp;(bout_update.userstatus=contact.userStatus);contact.birthDate&amp;&amp;
# (bout_update.birthdate_date=contact.birthDate);contact.dateShopCreated&amp;&amp;(bout_update.dateshopcreated_date=contact.dateShopCreated);contact.shopGold&amp;&amp;(bout_update.gold_merchant=contact.shopGold);contact.shopGold&amp;&amp;(bout_update.shop_product_count=contact.shopProductCount);contact.shopGold&amp;&amp;(bout_update.shop_name=contact.shopName);contact.shopGold&amp;&amp;(bout_update.shop_gold=contact.shopGold);contact.shopTransactionCount&amp;&amp;(bout_update.shop_transactioncount=contact.shopTransactionCount);contact.userMSISDNVerified&amp;&amp;
# (bout_update.userMSISDNVerified=contact.userMSISDNVerified);_bout.push(["properties",{customer_id:""+contact.userId,email:""+contact.userEmail,phone:""+contact.phoneNumber},{update:bout_update}])};</script><script type="text/javascript" id="">var contact=google_tag_manager["GTM-TN8CNF"].macro(5),_bout=_bout||[];contact?_bout.push(["identify",{customer_id:""+contact.userId,email:""+contact.userEmail,phone:""+contact.phoneNumber}]):_bout.push(["identify",{customer_id:"",email:"",phone:""}]);</script><script type="text/javascript" id="" src="https://ecs7.tokopedia.net/scripts/global.fingerprintjs2.1.4.2.min.js"></script><script type="text/javascript" id="">var contact=google_tag_manager["GTM-TN8CNF"].macro(6),uid=google_tag_manager["GTM-TN8CNF"].macro(7),uidCookie=getCookieUid("tuid"),d=new Date;d.setTime(d.getTime()+2592E6);var expires="expires\x3d"+d.toGMTString();contact?uidCookie?uid!=uidCookie&amp;&amp;(deleteCookieUid(),document.cookie="tuid\x3d"+uid+"; "+expires+"; path\x3d/"):document.cookie="tuid\x3d"+uid+"; path\x3d/;":uidCookie?(window.dataLayer=window.dataLayer||[],dataLayer.push({event:"nonAuthenticated",contactInfo:{userId:uidCookie}})):(window.dataLayer=window.dataLayer||[],dataLayer.push({event:"nonAuthenticated"}));
# function getCookieUid(b){b+="\x3d";for(var e=document.cookie.split(";"),c=0;c&lt;e.length;c++){for(var a=e[c];" "==a.charAt(0);)a=a.substring(1);if(0==a.indexOf(b))return a.substring(b.length,a.length)}return""}function deleteCookieUid(){document.cookie="tuid\x3d; path\x3d/; expires\x3dThu, 01 Jan 1970 00:00:01 GMT;"};</script><script type="text/javascript" id="">(function(b,f){function a(a,c,d,e){b.dataLayer=b.dataLayer||[];dataLayer.push({event:a,eventCategory:c,eventAction:d,eventLabel:e})}$(document).ready(function(){$(".top-admin.deposit-notif-container\x3ediv\x3ea.btn.btn-action").on("click",function(){a("clickCreateShop","Create Shop","Click","Create")});$("#shop-tab\x3ediv.dropdown-shop-empty\x3ediv\x3ea:first-child").on("click",function(){a("clickCreateShop","Create Shop","Click","Create")})})})(window);</script><script type="text/javascript" id="">var main_url="https://www.tokopedia.com/",recharge_url="https://pulsa.tokopedia.com/",recharge_api_url="https://pulsa-api.tokopedia.com/",recharge_banner_url="https://pulsa.tokopedia.com/",tiket_url="https://tiket.tokopedia.com/",user_id=google_tag_manager["GTM-TN8CNF"].macro(8),kai_station_1=google_tag_manager["GTM-TN8CNF"].macro(9),kai_station_2=google_tag_manager["GTM-TN8CNF"].macro(10),recharge_banner_big="https://ecs7.tokopedia.net/img/recharge/widget/banner-360x120-v2.jpg",recharge_banner_small="https://ecs7.tokopedia.net/img/recharge/widget/banner-200x120-v2.jpg",
# recharge_force_operator=0,recharge_cdn_version=6,widget_version="a";
# $(function(){if(document.createStyleSheet)document.createStyleSheet("https://ecs7.tokopedia.net/css/recharge-widget-desktop-v3.css?v\x3d"+recharge_cdn_version);else{var a="@import url('https://ecs7.tokopedia.net/css/recharge-widget-desktop-v3.css?v\x3d"+recharge_cdn_version+"');",b=document.createElement("link");b.rel="stylesheet";b.href="data:text/css,"+escape(a);document.getElementsByTagName("head")[0].appendChild(b);a="#digital_widget_desktop .dgw-dropdown__name, #digital_widget_desktop .dgw-dropdown__price { white-space: initial!important;word-break: initial!important }";a+=
# "#digital_widget_desktop ::-webkit-scrollbar {width: 7px; -webkit-appearance: none; }#digital_widget_desktop ::-webkit-scrollbar-thumb {border-radius: 4px; background-color: rgba(0, 0, 0, 0.5); box-shadow: 0 0 1px rgba(255, 255, 255, 0.5); }";a+="#digital_widget_desktop .dgw-dropdown {min-width: 214px; top: 33px; border-radius: 3px; }";b=document.createElement("style");b.type="text/css";b.innerHTML=a;document.getElementsByTagName("head")[0].appendChild(b)}a=!0;var e=!1;b=function(b){var a=decodeURIComponent(window.location.search.substring(1));
# a=a.split("\x26");var c;for(c=0;c&lt;a.length;c++){var d=a[c].split("\x3d");if(d[0]===b)return void 0===d[1]?!0:d[1]}};2==b("ab")&amp;&amp;(a=!1,widget_version="b");0==a&amp;&amp;(slick_option={slidesToShow:1,autoplay:!0,autoplaySpeed:5E3,dots:!0,arrows:!0,customPaging:function(b,a){return'\x3cspan class\x3d"slick-pagination-bullet"\x3e\x3c/span\x3e'},nextArrow:'\x3ca class\x3d"next"\x3e\x3cspan class\x3d"inner-slick-nav"\x3e\x3ci class\x3d"icon-chevron-right-alt"\x3e\x3c/i\x3e\x3c/span\x3e\x3c/a\x3e',prevArrow:'\x3ca class\x3d"prev"\x3e\x3cspan class\x3d"inner-slick-nav"\x3e\x3ci class\x3d"icon-chevron-left-alt"\x3e\x3c/i\x3e\x3c/span\x3e\x3c/a\x3e',
# pauseOnHover:!0,pauseOnDotsHover:!0},0==user_id?(a="@media (min-width: 1200px){ .home-promo-banner__container { width : 460px } .home-widget-digital__container { width: 700px } }",b=document.createElement("style"),b.type="text/css",b.innerHTML=a,document.getElementsByTagName("head")[0].appendChild(b),$(document).ready(function(){2!=$(".home-banner-center .banner-placeholder").length&amp;&amp;(e=!0);if(e)setTimeout(function(){$(".home-banner-center").slick("unslick");$(".home-banner-center").slick(slick_option);
# $(".home-banner-center").slick("setPosition");$(".home-banner-center").slick("refresh")},500);else{var b=".home-banner-center .banner-placeholder { display: none }",a=document.createElement("style");a.type="text/css";a.innerHTML=b;document.getElementsByTagName("head")[0].appendChild(a)}})):(a=".new-widget .widget-digital__container { width : 468px } .new-widget  h1 { font-size:16px } @media (min-width: 1200px){ .new-widget .widget-digital__container{ width : 690px } h1.pull-left { margin-bottom : 0 } .new-widget { margin-bottom : 15px } } .new-widget h1 + a { line-height : 40px }",
# b=document.createElement("style"),b.type="text/css",b.innerHTML=a,document.getElementsByTagName("head")[0].appendChild(b),$(document).ready(function(){$(".home-banner-full").slick("unslick");var a='\x3cdiv class\x3d"row-fluid new-widget"\x3e\x3c/div\x3e';$(a).insertBefore(".container + .container-fluid \x3e .row-fluid:first-child");temp=$(".maincontent-admin.maincontent-home \x3e .row-fluid:first-child").detach();$(temp).appendTo(".new-widget");$(".home-banner-full").slick(slick_option);$(".row-fluid.pull-left.content-container.mt-20").removeClass("mt-20");
# $("h1.pull-left.mb-15").removeClass("mb-15")})));$.getScript("https://ecs7.tokopedia.net/scripts/recharge-widget-desktop-v3.js?v\x3d"+recharge_cdn_version)});</script><iframe src="//asia.creativecdn.com/tags?id=pr_OkJQ9ozuKzXxEhoXlnra_home" width="1" height="1" scrolling="no" frameborder="0" style="display: none;"></iframe>
# <script type="text/javascript" id="">(function(){var contact=google_tag_manager["GTM-TN8CNF"].macro(11)})();function readCookie(name){var nameEQ=name+"\x3d";var ca=document.cookie.split(";");for(var i=0;i&lt;ca.length;i++){var c=ca[i];while(c.charAt(0)===" ")c=c.substring(1,c.length);if(c.indexOf(nameEQ)===0)return c.substring(nameEQ.length,c.length)}return null}
# function createCookie(name,value,days){var expires;if(days){var date=new Date;date.setTime(date.getTime()+days*24*60*60*1E3);expires="; expires\x3d"+date.toGMTString()}else expires="";document.cookie=name+"\x3d"+value+expires+";domain\x3d.tokopedia.com; path\x3d/"};</script><script type="text/javascript" id="">(function(){var b=google_tag_manager["GTM-TN8CNF"].macro(12);if(!window.jQuery){var a=document.createElement("script");a.src="https://code.jquery.com/jquery-1.12.4.min.js";a.type="text/javascript";document.getElementsByTagName("head")[0].appendChild(a)}void 0!=$("#mt-pre-approve").html()&amp;&amp;b&amp;&amp;b.shopId&amp;&amp;((a=checkCookie(b.shopId))?$("#mt-pre-approve").html(""):(a=google_tag_manager["GTM-TN8CNF"].macro(19),a=a+"/micro/mt/preapprove/"+b.shopId,$.ajax({url:a,type:"GET",success:function(a){"null"!=a&amp;&amp;a?$("#mt-pre-approve").html(a):setCookie("NoPreApprove",
# b.shopId,1)},error:function(a,c,e){setCookie("NoPreApprove",b.shopId,1)}})))})();function setCookie(b,a,d){var c=new Date;c.setTime(c.getTime()+36E5*d);d="expires\x3d"+c.toGMTString();document.cookie=b+"\x3d"+a+";"+d+";path\x3d/"}function getCookie(b){b+="\x3d";var a=decodeURIComponent(document.cookie);a=a.split(";");for(var d=0;d&lt;a.length;d++){for(var c=a[d];" "==c.charAt(0);)c=c.substring(1);if(0==c.indexOf(b))return c.substring(b.length,c.length)}return""}
# function checkCookie(b){var a=getCookie("NoPreApprove");return a==b?a:""};</script><iframe id="spWorker" src="https://tokopedia.api.sociaplus.com/worker.html" style="display: none;"></iframe><script type="text/javascript" id="">twttr.conversion.trackPid("nu522",{tw_sale_amount:google_tag_manager["GTM-TN8CNF"].macro(23),tw_order_quantity:google_tag_manager["GTM-TN8CNF"].macro(24)});</script>
# <noscript>
# &lt;img height="1" width="1" style="display:none;" alt="" src="https://analytics.twitter.com/i/adsct?txn_id=nu522&amp;amp;p_id=Twitter&amp;amp;tw_sale_amount=0&amp;amp;tw_order_quantity=0"&gt;
# &lt;img height="1" width="1" style="display:none;" alt="" src="//t.co/i/adsct?txn_id=nu522&amp;amp;p_id=Twitter&amp;amp;tw_sale_amount=0&amp;amp;tw_order_quantity=0"&gt;
# </noscript>
# <script type="text/javascript" id="">window.dataLayer=window.dataLayer||[];function gtag(){dataLayer.push(arguments)}gtag("js",new Date);gtag("config","DC-8603974");</script>
#
# <script type="text/javascript" id="">fingerprint_get_cookie=function(a){return 0&lt;document.cookie.length&amp;&amp;(c_start=document.cookie.indexOf(a+"\x3d"),-1!=c_start)?(c_start=c_start+a.length+1,c_end=document.cookie.indexOf(";",c_start),-1==c_end&amp;&amp;(c_end=document.cookie.length),unescape(document.cookie.substring(c_start,c_end))):""};
# $(document).ready(function(){(new Fingerprint2).get(function(a){cookie_name="_BID_TOKOPEDIA_";get_cookie_bid=fingerprint_get_cookie(cookie_name);if(get_cookie_bid!=a){var b=new Date;b.setTime(b.getTime()+31536E8);domain=location.hostname;domain_parent=domain.replace(/^(.+\.)?([^\.]+\.[^\.]+)$/,"$2");document.cookie=cookie_name+"\x3d"+a+"; expires\x3d"+b.toGMTString()+"; domain\x3d."+domain_parent+"; path\x3d/"}})});</script><div id="criteo-tags-div" style="display: none;"><iframe height="0" width="0" src="//dis.as.criteo.com/dis/dis.aspx?p=20100&amp;cb=42283850241&amp;ref=&amp;sc_r=1280x800&amp;sc_d=24" style="display: none;"></iframe></div><script src="https://analytics.twitter.com/i/adsct?p_id=Twitter&amp;p_user_id=0&amp;txn_id=nu522&amp;tw_sale_amount=undefined&amp;tw_order_quantity=undefined&amp;tw_iframe_status=0&amp;tpx_cb=twttr.conversion.loadPixels&amp;tw_document_href=https%3A%2F%2Fwww.tokopedia.com%2F" type="text/javascript"></script><script src="https://analytics.twitter.com/i/adsct?p_id=Twitter&amp;p_user_id=0&amp;txn_id=nuwgn&amp;events=%5B%5B%22pageview%22%2Cnull%5D%5D&amp;tw_sale_amount=0&amp;tw_order_quantity=0&amp;tw_iframe_status=0&amp;tpx_cb=twttr.conversion.loadPixels&amp;tw_document_href=https%3A%2F%2Fwww.tokopedia.com%2F" type="text/javascript"></script><script src="https://analytics.twitter.com/i/adsct?p_id=Twitter&amp;p_user_id=0&amp;txn_id=nuwgn&amp;events=%5B%5B%22pageview%22%2Cnull%5D%5D&amp;tw_sale_amount=0&amp;tw_order_quantity=0&amp;tw_iframe_status=0&amp;tpx_cb=twttr.conversion.loadPixels&amp;tw_document_href=https%3A%2F%2Fwww.tokopedia.com%2F" type="text/javascript"></script></body></html>

# %%
f = open('sample.txt','r')
data = f.read()
data_email = ''
data_password = ''
for x in data.split('\n'):
    key,value = x.split(':')
    if key == 'email':
        data_email = value
    elif key == 'password':
        data_password = value
    else:
        print 'tidak tau'

# %%
print data_email
print data_password
# Out:
# email123coba@gmail.com
# samplepass123

# %%
email = browser.find_element_by_id('email')
email.clear()
email.click()
email.send_keys(data_email)

# %%
password = browser.find_element_by_id('password')
password.clear()
password.click()
password.send_keys(data_password)

# %%
btn_login = browser.find_element_by_id('login-submit')
btn_login.click()
